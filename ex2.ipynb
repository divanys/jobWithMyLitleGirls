# %%
import pandas as pd

raw = 'https://raw.githubusercontent.com/jorisvandenbossche/pandas-tutorial/master/data/titanic.csv'
datf = pd.read_csv(raw)
print(datf)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
datf.to_csv('./exempleWriteCsv.csv')

# %%
datf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
datf.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
datf[['Age', 'Name']]
# Out:
#       Age                                               Name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886  27.0                              Montvila, Rev. Juozas
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                              Behr, Mr. Karl Howell
# 890  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
datf.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
datf.iloc[[127, 92, 2], [1, 3, 6]]
# Out:
#      Survived                         Name  SibSp
# 127         1    Madsen, Mr. Fridtjof Arne      0
# 92          0  Chaffee, Mr. Herbert Fuller      1
# 2           1       Heikkinen, Miss. Laina      0

# %%
datf[datf['Age'] < 1]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# ...

# %%
datf[(datf['Age'] == 34) | (datf['Age'] == 43)].shape
# .size = 20 * 12
# Out:
# (20, 12)

# %%
datf["Age"].isna().sum()
# Out:
# 177

# %%
datf.loc[datf['Age'].notna(), 'Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 714, dtype: int64

# %%
datf.sort_values('Name')[(datf['Age'] == 34) | (datf['Age'] == 43)]
# Out:
# /tmp/ipykernel_7438/1060139367.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datf.sort_values('Name')[(datf['Age'] == 34) | (datf['Age'] == 43)]
#      PassengerId  Survived  Pclass  \
# 21            22         1       2
# 668          669         0       3
# 616          617         0       3
# 98            99         1       2
# 416          417         1       2
# 405          406         0       2
# 576          577         1       2
# 722          723         0       2
# 678          679         0       3
# 314          315         0       2
# 818          819         0       3
# 202          203         0       3
# 99           100         0       2
# 516          517         1       2
# 461          462         0       3
# 800          801         0       2
# 476          477         0       2
# 779          780         1       1
# 447          448         1       1
# 758          759         0       3
#
# ...

# %%
datf.sort_values(['Age', 'Name'], ascending=[False, True]).

# %%
df2 = datf.copy(deep=True) # если не будет труе, то дт2 будет меняться при изменении датф, тк он будет ссылкой на датф, а не реал копией

# %%
cdf = pd.concat([datf, df2], axis=0) # axis=1
cdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mdf = pd.DataFrame(index=datf.index)
mdf['PassengerId'] = datf['PassengerId']
mdf['evenId'] = mdf['PassengerId'].apply(lambda x: x % 2 == 0)
pd.merge(datf, mdf, how='inner')

# %%
mdf
# Out:
#      PassengerId  evenId
# 0              1   False
# 1              2    True
# 2              3   False
# 3              4    True
# 4              5   False
# ..           ...     ...
# 886          887   False
# 887          888    True
# 888          889   False
# 889          890    True
# 890          891   False
#
# [891 rows x 2 columns]

# %%
datf.count()
# datf['Age'].count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
datf['Age'].mean(), datf['Age'].median()
# Out:
# (29.69911764705882, 28.0)

# %%
datf.groupby('Sex')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
datf.groupby(['Sex', 'Survived'])['Age'].agg(['mean', 'max'])
# Out:
#                       mean   max
# Sex    Survived
# female 0         25.046875  57.0
#        1         28.847716  63.0
# male   0         31.618056  74.0
#        1         27.276022  80.0

# %%
datf['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
datf.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
datf['Age'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

plt.plot(datf['Age'])

# %%
# plt.bar(datf['Age'], datf['Age'].value_counts())

# %%
datf['PassengerId']
# Out:
# (891,)

# %%
datf['Age'].plot(kind='kde', xlim=[0, 80])
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
datf.groupby('Sex')['Age'].plot(kind='kde', xlim=[0, 80], legend=True)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
import numpy as np
a = np.random.randint(1, 10, (2, 5, 5))
a1 = np.sum(a[a % 3 == 0])
print(a)
print(a1)
# Out:
# [[[1 4 6 1 6]
#   [3 3 6 4 5]
#   [7 7 4 8 9]
#   [1 7 6 5 7]
#   [7 9 1 2 3]]
#
#  [[4 5 9 2 3]
#   [6 4 3 7 9]
#   [3 1 2 2 4]
#   [2 5 3 6 2]
#   [6 1 3 3 9]]]
# 114
